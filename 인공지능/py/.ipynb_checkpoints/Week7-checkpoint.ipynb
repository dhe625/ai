# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.array([1,2,3,4])
y = x*5
print(x,y)
plt.plot(x,y)
plt.show()
# Out:
# [1 2 3 4] [ 5 10 15 20]

# %%
plt.title('My Graph')
plt.xlabel('X-label')
plt.ylabel('Y-label')
plt.plot(x,y)
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.array([1,2,3,4])
y = x*5

plt.xlabel('X-label')
plt.ylabel('Y-label')

# default는 'b-' b : blue, - : line
# go 사용 g : green, o : 'o'로 표현
plt.plot(x,y,'go')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x1 = np.array([1,2,3,4])
y1 = x1*5

x2 = np.array([3,4,6,8])
y2 = x2*3

plt.plot(x1,y1,'go',x2,y2,'r-')
plt.show()

# %%
import matplotlib
from matplotlib import font_manager, rc
from matplotlib import pyplot as plt
import numpy as np

font_location = "C:\Windows\Fonts\malgun.ttf" # 폰트 위치
font_name = font_manager.FontProperties(fname = font_location).get_name()
matplotlib.rc('font', family = font_name)

x = np.array([1,2,3,4])
y = x1*5

plt.title('나의 그래프')
plt.xlabel('X-축')
plt.ylabel('Y-축')
plt.plot(x,y)
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

plt.figure() # figure 생성

plt.subplot(2,1,1) # row 2개, col 1개 중 1번
x1 = np.array([1,2,3,4])
y1 = x1*5
plt.plot(x1, y1, 'ro')

plt.subplot(2,1,2) # row 2개, col 1개 중 2번
x2 = np.array([3,4,6,8])
y2 = x2*5
plt.plot(x2, y2, 'y-')

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.array([1,2,3,4])
y = x*5

plt.xlabel('X-label')
plt.ylabel('Y-label')

plt.text(3, 14, 'point')

plt.grid() # default = True
plt.plot(x,y,'ro')

plt.show()

# %%
import matplotlib
from matplotlib import font_manager, rc
from matplotlib import pyplot as plt
import numpy as np

# 폰트에 따라서 음수인 경우, '-' 사인이 표출되지 않는 경우가 있음
# 이를 해결하기 위해 다른 폰트를 적용
font_location = "C:\Windows\Fonts\malgun.ttf" # 폰트 위치
font_name = font_manager.FontProperties(fname = font_location).get_name()
matplotlib.rc('font', family = font_name)

# 정규분포를 가지는 1차원 array 실수 1000개를 생성
# np.random.randn(n,m)일 경우 n * m개의 2차원 실수 생성
x = np.random.randn(1000)
y1 = np.random.randn(len(x))
y2 = np.exp(x)

plt.subplot(1,2,1)
plt.scatter(x, y1,s = 1, alpha = 0.5)
# s : point size, alpha : 투명도

plt.xlim(-4.0, 4.0)
plt.ylim(-5, 30)
plt.grid()

plt.subplot(1,2,2)
plt.scatter(x, y2,s = 1, alpha = 0.5)
plt.xlim(-4.0, 4.0)
plt.ylim(-5, 30)
plt.grid()

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.array([1,2,3,4,5,6])
y = np.array([3,1,4,2,8,2])

plt.bar(x,y, color = 'magenta')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

y = np.array([3,1,4,2,8,2])

plt.pie(y)
plt.show()
